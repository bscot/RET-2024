# %% [markdown]
# <a href="https://colab.research.google.com/github/bscot/RET-2024/blob/main/intro_to_CCL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# !mamba install pyccl
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:07
# 🔁 Restarting kernel...
#
# Looking for: ['pyccl']
#
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch     1%[+] 0.2s
# conda-forge/linux-64   1%
# conda-forge/noarch    20%[+] 0.3s
# conda-forge/linux-64  20%
# conda-forge/noarch    69%[+] 0.4s
# conda-forge/linux-64  29%
# conda-forge/noarch    89%conda-forge/noarch
# [+] 0.5s
# conda-forge/linux-64  38%[+] 0.6s
# conda-forge/linux-64  61%[+] 0.7s
# conda-forge/linux-64  88%[+] 0.8s
# conda-forge/linux-64  96%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - pyccl
#    - ca-certificates
#    - certifi
#    - openssl
#
#
# ...

# %%
import matplotlib.pyplot as plt # plotting
import numpy as np # general math and array manipulation
import pyccl # most cosmology
import pandas as pd # statistics and better data structures
from scipy import stats # statistical functions
import astropy # convenience functions for astronomy
